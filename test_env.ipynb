# %%
from dotenv import load_dotenv
load_dotenv(".env")
# Out:
# True

# %%
import os
print(os.getenv("BINANCE_API_KEY"))
print(os.getenv("BINANCE_API_SECRET"))
# Out:
# yZSBr2NYhNCyzWfb9jal2Byu3ThVbpx5eZc1lkwjC69huHCm0hvK90OLRaEI0HvR
# jb5ynHgM7EmwwSAQZs8c0ecJ26UcQ042970D4nM0jQH91gFYtaCKL5n1Yr7jOQ37
